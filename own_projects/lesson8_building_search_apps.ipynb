# %% [markdown]
# In order to run the following noteboooks, if you haven't done yet, you need to set the openai key inside .env file as `OPENAI_API_KEY`

# %%
import os
from openai import OpenAI

from dotenv import load_dotenv
load_dotenv()

api_key = os.environ['OPEN_AI_API_KEY']
client = OpenAI(api_key=api_key)

import numpy as np
import pandas as pd

#Functions made for ease of use
def add_to_context(message_log, conversation, role = "user"):
    message_log.append({"role": role, "content": conversation})

def submit_to_gpt(message_log):
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=message_log
        )   
    print(response.choices[0].message.content)
    add_to_context(message_log=message_log, role = "assistant", conversation = response.choices[0].message.content)

def converse(conversation, role="user", system_start = None, message_log = None):
    if not message_log:
        message_log = []
        if system_start:
            add_to_context(message_log, system_start, "system")
    
    add_to_context(message_log, conversation, role)
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=message_log
    )
    response_content = response.choices[0].message.content
    add_to_context(message_log, response_content, "assistant")
    print(response_content)
    return message_log


model = 'text-embedding-ada-002'

SIMILARITIES_RESULTS_THRESHOLD = 0.75
DATASET_NAME = "embedding_index_3m.json"

# %% [markdown]
# Next, we are going to load the Embedding Index into a Pandas Dataframe. The Embedding Index is stored in a JSON file called `embedding_index_3m.json`. The Embedding Index contains the Embeddings for each of the YouTube transcripts up until late Oct 2023.

# %%
def load_dataset(source: str) -> pd.core.frame.DataFrame:
    # Load the video session index
    pd_vectors = pd.read_json(source)
    return pd_vectors.drop(columns=["text"], errors="ignore").fillna("")

# %% [markdown]
# Next, we are going to create a function called `get_videos` that will search the Embedding Index for the query. The function will return the top 5 videos that are most similar to the query. The function works as follows:
#
# 1. First, a copy of the Embedding Index is created.
# 2. Next, the Embedding for the query is calculated using the OpenAI Embedding API.
# 3. Then a new column is created in the Embedding Index called `similarity`. The `similarity` column contains the cosine similarity between the query Embedding and the Embedding for each video segment.
# 4. Next, the Embedding Index is filtered by the `similarity` column. The Embedding Index is filtered to only include videos that have a cosine similarity greater than or equal to 0.75.
# 5. Finally, the Embedding Index is sorted by the `similarity` column and the top 5 videos are returned.

# %%
def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

def get_videos(
    query: str, dataset: pd.core.frame.DataFrame, rows: int
) -> pd.core.frame.DataFrame:
    # create a copy of the dataset
    video_vectors = dataset.copy()

    # get the embeddings for the query    
    query_embeddings = client.embeddings.create(input=query, model=model).data[0].embedding

    # create a new column with the calculated similarity for each row
    video_vectors["similarity"] = video_vectors["ada_v2"].apply(
        lambda x: cosine_similarity(np.array(query_embeddings), np.array(x))
    )

    # filter the videos by similarity
    mask = video_vectors["similarity"] >= SIMILARITIES_RESULTS_THRESHOLD
    video_vectors = video_vectors[mask].copy()

    # sort the videos by similarity
    video_vectors = video_vectors.sort_values(by="similarity", ascending=False).head(
        rows
    )

    # return the top rows
    return video_vectors.head(rows)

# %% [markdown]
# This function is very simple, it just prints out the results of the search query.

# %%
def display_results(videos: pd.core.frame.DataFrame, query: str):
    def _gen_yt_url(video_id: str, seconds: int) -> str:
        """convert time in format 00:00:00 to seconds"""
        return f"https://youtu.be/{video_id}?t={seconds}"

    print(f"\nVideos similar to '{query}':")
    for _, row in videos.iterrows():
        youtube_url = _gen_yt_url(row["videoId"], row["seconds"])
        print(f" - {row['title']}")
        print(f"   Summary: {' '.join(row['summary'].split()[:15])}...")
        print(f"   YouTube: {youtube_url}")
        print(f"   Similarity: {row['similarity']}")
        print(f"   Speakers: {row['speaker']}")

# %% [markdown]
# 1. First, the Embedding Index is loaded into a Pandas Dataframe.
# 2. Next, the user is prompted to enter a query.
# 3. Then the `get_videos` function is called to search the Embedding Index for the query.
# 4. Finally, the `display_results` function is called to display the results to the user.
# 5. The user is then prompted to enter another query. This process continues until the user enters `exit`.
#
# ![](media/notebook_search.png)
#
# You will be prompted to enter a query. Enter a query and press enter. The application will return a list of videos that are relevant to the query. The application will also return a link to the place in the video where the answer to the question is located.
#
# Here are some queries to try out:
#
# - What is Azure Machine Learning?
# - How do convolutional neural networks work?
# - What is a neural network?
# - Can I use Jupyter Notebooks with Azure Machine Learning?
# - What is ONNX?

# %%
pd_vectors = load_dataset(DATASET_NAME)

# get user query from imput
while True:
    query = input("Enter a query: ")
    if query == "exit":
        break
    videos = get_videos(query, pd_vectors, 5)
    display_results(videos, query)
# Out:
# Videos similar to 'What is Azure Machine Learning?':
#  - Azure Machine Learning Studio
#    Summary: Stephanie Lindsay, a Program Manager at Azure Machine Learning, introduces the new Azure Machine Learning...
#    YouTube: https://youtu.be/JNa4VV0d8T0?t=0
#    Similarity: 0.8765188546270597
#    Speakers: Stephanie Lindsay
#  - Time Series Forecasting with Azure Machine Learning
#    Summary: In this video, the speaker discusses time series forecasting with Azure Machine Learning. They demonstrate...
#    YouTube: https://youtu.be/mGr_c2UnOUI?t=7
#    Similarity: 0.8731159335576165
#    Speakers: Hi, everyone. In this video, we are going to talk about time series forecasting with Azure Machine Learning.
#  - Get Started with Azure Machine Learning with Visual Studio Code Tools
#    Summary: In this episode of the AI Show, Chris, a Program Manager in Azure AI Team,...
#    YouTube: https://youtu.be/u5tqeLAWLPU?t=0
#    Similarity: 0.8729568969006328
#    Speakers: Chris
#  - What’s new with Azure Machine Learning
#    Summary: Azure Machine Learning is a powerful tool for training and deploying machine learning models. It...
#    YouTube: https://youtu.be/YlWCeY_CWEg?t=914
#    Similarity: 0.8729016231202552
#    Speakers: Chris
#  - What’s new with Azure Machine Learning
#    Summary: Chris from Azure Machine Learning provides an overview of the new capabilities in Azure Machine...
#    YouTube: https://youtu.be/YlWCeY_CWEg?t=0
#    Similarity: 0.8676342194782247
#    Speakers: Chris
#
# Videos similar to '':
#
# Videos similar to 'How to eat food':
#  - Visual Search Toolkit with Azure AI
#    Summary: The video demonstrates the process of using Azure AI's visual search toolkit to convert images...
#    YouTube: https://youtu.be/ZEwaqkMkLUY?t=1102
#    Similarity: 0.7521054038122813
#    Speakers: Serge Retkowsky
#  - Bing Visual Search
#    Summary: In this video, Robbie from Bing Visual Search explains how to build skills on top...
#    YouTube: https://youtu.be/TjcPp5te3X4?t=368
#    Similarity: 0.7512586309790844
#    Speakers: Robbie
#  - Bing Visual Search
#    Summary: Developers can leverage the Bing Visual Search API to create skills that provide information based...
#    YouTube: https://youtu.be/TjcPp5te3X4?t=183
#    Similarity: 0.7511734912777113
#    Speakers: Robbie
#  - Igniting developer innovation with Vector search and Azure OpenAI
#    Summary: In this video, the presenter demonstrates how to create a recipe assistant using Azure OpenAI...
#    YouTube: https://youtu.be/YvmcHmxjqfM?t=1102
#    Similarity: 0.7510617234101656
#    Speakers: Derek Legenzof
#
# Videos similar to '':
#
# Videos similar to 'How to jump rope':
#  - Machine Learning with Azure Notebooks
#    Summary: To get started with machine learning, you only need a few lines of code. The...
#    YouTube: https://youtu.be/LbtzVLk1ADc?t=550
#    Similarity: 0.7549083318008047
#    Speakers: Paige, Lo
#  - New reinforcement learning methods aim to improve AI in gaming and beyond
#    Summary: In this interactive experience, a trained reinforcement learning agent collaborates with a human player in...
#    YouTube: https://youtu.be/tjVl1_sVlHw?t=553
#    Similarity: 0.7540199806784401
#    Speakers: Dr. Katja Hofmann, Seth
#  - Data Science Virtual Machine
#    Summary: The Windows Data Science Virtual Machine provides a pre-configured environment for data scientists and AI...
#    YouTube: https://youtu.be/pHYrQo2q1ho?t=1098
#    Similarity: 0.750374972078772
#    Speakers: Gopi Krishna Kumar
#
# Videos similar to '':
#
# Videos similar to 'Escape':
#  - Conversational AI and human agents working together
#    Summary: This video demonstrates how to engage with consumers through web messaging and SMS using the...
#    YouTube: https://youtu.be/Z0IDiekbOp4?t=1445
#    Similarity: 0.7601345391745017
#    Speakers: Artur Laksberg, Robert Standefer
#  - Advanced Language Understanding & Language Generation with Bot Framework Composer
#    Summary: The video demonstrates how to use advanced language generation and understanding capabilities in Power Automate...
#    YouTube: https://youtu.be/wG8emu4v6hk?t=920
#    Similarity: 0.758654331401765
#    Speakers: Vash walks Anakin, boishakh, Bhishma
#  - Inside Immersive Reader
#    Summary: Microsoft's Immersive Reader, a tool that helps improve reading comprehension, is now available in over...
#    YouTube: https://youtu.be/jBfBnBU44dQ?t=369
#    Similarity: 0.7562092311129414
#    Speakers: Mike Tholfsen
#  - Computer Vision for Spatial Analysis
#    Summary: In this video, the speaker discusses the responsible use of AI in spatial analysis. They...
#    YouTube: https://youtu.be/n8ixE6ik9zQ?t=371
#    Similarity: 0.7558515382638319
#    Speakers: Adina Trufinescu
#  - Bringing AI to the Edge
#    Summary: In this video, we learn about the second phase of the maintenance process, where the...
#    YouTube: https://youtu.be/fnt64_iaweg?t=924
#    Similarity: 0.7545443791683337
#    Speakers: Phani Mutyala
#
# Videos similar to '':
#
# Videos similar to '':
#
# Videos similar to '':
#
# Videos similar to '':
#
# Videos similar to '':
#
# Videos similar to '':
